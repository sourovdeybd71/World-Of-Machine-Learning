# %% [markdown]
# <a href="https://colab.research.google.com/github/sourovdeybd71/World-Of-Machine-Learning/blob/main/WebScrapping_GDP_Data_extraction_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy
# !pip install lxml

# %%
import numpy as np
import pandas as pd

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %%
tables = pd.read_html(URL)
df = tables[3]
df
# Out:
#     Country/Territory UN region IMF[1][13]            World Bank[14]  \
#     Country/Territory UN region   Estimate       Year       Estimate
# 0               World         —  105568776       2023      100562011
# 1       United States  Americas   26854599       2023       25462700
# 2               China      Asia   19373586  [n 1]2023       17963171
# 3               Japan      Asia    4409738       2023        4231141
# 4             Germany    Europe    4308854       2023        4072192
# ..                ...       ...        ...        ...            ...
# 209          Anguilla  Americas          —          —              —
# 210          Kiribati   Oceania        248       2023            223
# 211             Nauru   Oceania        151       2023            151
# 212        Montserrat  Americas          —          —              —
# 213            Tuvalu   Oceania         65       2023             60
#
#                United Nations[15]
# ...

# %%
df.columns = range(df.shape[1])
df.columns
# Out:
# RangeIndex(start=0, stop=8, step=1)

# %%
df = df[[0,2]]
df
# Out:
#                  0          2
# 0            World  105568776
# 1    United States   26854599
# 2            China   19373586
# 3            Japan    4409738
# 4          Germany    4308854
# ..             ...        ...
# 209       Anguilla          —
# 210       Kiribati        248
# 211          Nauru        151
# 212     Montserrat          —
# 213         Tuvalu         65
#
# [214 rows x 2 columns]

# %%
#top 10 economies
df = df.iloc[1:11,:]
df.columns = ['Country','GDP (Million USD)']
df
# Out:
#            Country  GDP (Million USD)
# 1    United States           26854.60
# 2            China           19373.59
# 3            Japan            4409.74
# 4          Germany            4308.85
# 5            India            3736.88
# 6   United Kingdom            3158.94
# 7           France            2923.49
# 8            Italy            2169.74
# 9           Canada            2089.67
# 10          Brazil            2081.24

# %%
df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)

df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000

df[['GDP (Million USD)']] = np.round(df[['GDP (Million USD)']], 2)

df.rename(columns = {'GDP (Million USD)' : 'GDP (Billion USD)'})
# Out:
# <ipython-input-26-2b1982ec9dd3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['GDP (Million USD)'] = df['GDP (Million USD)'].astype(int)
# <ipython-input-26-2b1982ec9dd3>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[['GDP (Million USD)']] = df[['GDP (Million USD)']]/1000
# <ipython-input-26-2b1982ec9dd3>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df.to_csv('./Largest_economies.csv')
